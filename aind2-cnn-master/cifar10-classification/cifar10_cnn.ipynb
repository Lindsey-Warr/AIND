# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.
# Downloading data from http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# Untaring file...

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054.0
# Trainable params: 528,054.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=30,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/30
# Epoch 00000: val_loss improved from inf to 1.25135, saving model to model.weights.best.hdf5
# 64s - loss: 1.5716 - acc: 0.4282 - val_loss: 1.2513 - val_acc: 0.5490
# Epoch 2/30
# Epoch 00001: val_loss improved from 1.25135 to 1.08364, saving model to model.weights.best.hdf5
# 67s - loss: 1.2570 - acc: 0.5486 - val_loss: 1.0836 - val_acc: 0.6178
# Epoch 3/30
# Epoch 00002: val_loss improved from 1.08364 to 1.01688, saving model to model.weights.best.hdf5
# 67s - loss: 1.1268 - acc: 0.5989 - val_loss: 1.0169 - val_acc: 0.6214
# Epoch 4/30
# Epoch 00003: val_loss improved from 1.01688 to 0.93948, saving model to model.weights.best.hdf5
# 68s - loss: 1.0433 - acc: 0.6277 - val_loss: 0.9395 - val_acc: 0.6712
# Epoch 5/30
# Epoch 00004: val_loss improved from 0.93948 to 0.88142, saving model to model.weights.best.hdf5
# 64s - loss: 0.9803 - acc: 0.6532 - val_loss: 0.8814 - val_acc: 0.6858
# Epoch 6/30
# Epoch 00005: val_loss improved from 0.88142 to 0.84465, saving model to model.weights.best.hdf5
# 64s - loss: 0.9257 - acc: 0.6724 - val_loss: 0.8447 - val_acc: 0.6996
# Epoch 7/30
# Epoch 00006: val_loss improved from 0.84465 to 0.82213, saving model to model.weights.best.hdf5
# 64s - loss: 0.8830 - acc: 0.6857 - val_loss: 0.8221 - val_acc: 0.7112
# Epoch 8/30
# Epoch 00007: val_loss improved from 0.82213 to 0.80743, saving model to model.weights.best.hdf5
# 64s - loss: 0.8460 - acc: 0.7005 - val_loss: 0.8074 - val_acc: 0.7158
# Epoch 9/30
# Epoch 00008: val_loss did not improve
# 65s - loss: 0.8107 - acc: 0.7141 - val_loss: 0.8085 - val_acc: 0.7084
# Epoch 10/30
# Epoch 00009: val_loss improved from 0.80743 to 0.79149, saving model to model.weights.best.hdf5
# 65s - loss: 0.7804 - acc: 0.7221 - val_loss: 0.7915 - val_acc: 0.7256
# Epoch 11/30
# Epoch 00010: val_loss improved from 0.79149 to 0.76234, saving model to model.weights.best.hdf5
# 66s - loss: 0.7539 - acc: 0.7344 - val_loss: 0.7623 - val_acc: 0.7368
# Epoch 12/30
# Epoch 00011: val_loss improved from 0.76234 to 0.75095, saving model to model.weights.best.hdf5
# 64s - loss: 0.7277 - acc: 0.7408 - val_loss: 0.7510 - val_acc: 0.7420
# Epoch 13/30
# Epoch 00012: val_loss did not improve
# 65s - loss: 0.7045 - acc: 0.7497 - val_loss: 0.7601 - val_acc: 0.7408
# Epoch 14/30
# Epoch 00013: val_loss improved from 0.75095 to 0.73855, saving model to model.weights.best.hdf5
# 66s - loss: 0.6845 - acc: 0.7578 - val_loss: 0.7386 - val_acc: 0.7424
# Epoch 15/30
# Epoch 00014: val_loss did not improve
# 65s - loss: 0.6739 - acc: 0.7622 - val_loss: 0.7631 - val_acc: 0.7350
# Epoch 16/30
# Epoch 00015: val_loss improved from 0.73855 to 0.73609, saving model to model.weights.best.hdf5
# 64s - loss: 0.6488 - acc: 0.7695 - val_loss: 0.7361 - val_acc: 0.7436
# Epoch 17/30
# Epoch 00016: val_loss improved from 0.73609 to 0.73319, saving model to model.weights.best.hdf5
# 65s - loss: 0.6374 - acc: 0.7722 - val_loss: 0.7332 - val_acc: 0.7444
# Epoch 18/30
# Epoch 00017: val_loss improved from 0.73319 to 0.71919, saving model to model.weights.best.hdf5
# 68s - loss: 0.6215 - acc: 0.7787 - val_loss: 0.7192 - val_acc: 0.7554
# Epoch 19/30
# Epoch 00018: val_loss did not improve
# 66s - loss: 0.6087 - acc: 0.7847 - val_loss: 0.7364 - val_acc: 0.7508
# Epoch 20/30
# Epoch 00019: val_loss did not improve
# 64s - loss: 0.5963 - acc: 0.7862 - val_loss: 0.7464 - val_acc: 0.7420
# Epoch 21/30
# Epoch 00020: val_loss did not improve
# 65s - loss: 0.5756 - acc: 0.7948 - val_loss: 0.7290 - val_acc: 0.7562
# Epoch 22/30
# Epoch 00021: val_loss did not improve
# 64s - loss: 0.5718 - acc: 0.7944 - val_loss: 0.7418 - val_acc: 0.7442
# Epoch 23/30
# Epoch 00022: val_loss did not improve
# 68s - loss: 0.5573 - acc: 0.8002 - val_loss: 0.7546 - val_acc: 0.7520
# Epoch 24/30
# Epoch 00023: val_loss did not improve
# 68s - loss: 0.5515 - acc: 0.8021 - val_loss: 0.7438 - val_acc: 0.7548
# Epoch 25/30
# Epoch 00024: val_loss did not improve
# 65s - loss: 0.5394 - acc: 0.8069 - val_loss: 0.7315 - val_acc: 0.7496
# Epoch 26/30
# Epoch 00025: val_loss did not improve
# 66s - loss: 0.5298 - acc: 0.8106 - val_loss: 0.7387 - val_acc: 0.7520
# Epoch 27/30
# Epoch 00026: val_loss did not improve
# 65s - loss: 0.5284 - acc: 0.8090 - val_loss: 0.7408 - val_acc: 0.7448
# Epoch 28/30
# Epoch 00027: val_loss did not improve
# 64s - loss: 0.5094 - acc: 0.8186 - val_loss: 0.7356 - val_acc: 0.7548
# Epoch 29/30
# Epoch 00028: val_loss did not improve
# 66s - loss: 0.5062 - acc: 0.8197 - val_loss: 0.7323 - val_acc: 0.7530
# Epoch 30/30
# Epoch 00029: val_loss did not improve
# 66s - loss: 0.4997 - acc: 0.8219 - val_loss: 0.7641 - val_acc: 0.7442

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.7452

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
